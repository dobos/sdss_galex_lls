# %%
import astropy
import pyigm
import linetools

# %%
linetools.test()
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.6.6, pytest-3.6.2, py-1.5.3, pluggy-0.6.0
#
# Running tests with Astropy version 3.0.5.
# Running tests in ProgramData\Anaconda3\lib\site-packages\linetools.
#
# Date: 2019-02-12T18:23:05
#
# Platform: Windows-10-10.0.17763-SP0
#
# Executable: C:\ProgramData\Anaconda3\python.exe
#
# Full Python Version:
# 3.6.6 |Anaconda custom (64-bit)| (default, Jun 28 2018, 11:27:44) [MSC v.1900 64 bit (AMD64)]
#
# encodings: sys: utf-8, locale: cp1252, filesystem: utf-8
# byteorder: little
# float info: dig: 15, mant_dig: 15
#
# Numpy: 1.15.4
# Scipy: 1.1.0
# Matplotlib: 2.2.2
# h5py: 2.8.0
# Pandas: 0.23.1
# astropy_helpers: 3.0.2
# Using Astropy options: remote_data: none.
#
# rootdir: C:\, inifile:
# plugins: remotedata-0.3.0, openfiles-0.3.0, doctestplus-0.1.3, arraydiff-0.2
# collected 233 items
#
# ...
